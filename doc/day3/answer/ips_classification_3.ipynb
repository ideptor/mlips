# %% [markdown]
# # Feature Engineering
#
# - 신뢰도가 낮은 Feature의 갯수 줄이기

# %% [markdown]
# # 데이터 불러오기

# %%
import pandas as pd

df_data = pd.read_csv('trace.csv')
df_data.head()
# Out:
#    timestamp  region   latitude  longitude  20:19:00:00:03:21  \
# 0     61.472       0  43.718277  10.421566                NaN
# 1     68.396       0  43.718301  10.421608                NaN
# 2     72.410       1  43.718326  10.421649                NaN
# 3     76.387       1  43.718350  10.421691                NaN
# 4     80.398       1  43.718375  10.421733                NaN
#
#    20:19:00:00:02:81  20:19:00:00:01:43  20:19:00:00:03:23  20:19:00:00:00:98  \
# 0                NaN                NaN                NaN              -37.0
# 1                NaN                NaN                NaN              -48.0
# 2                NaN                NaN                NaN              -66.0
# 3                NaN                NaN                NaN              -68.0
# 4                NaN                NaN                NaN              -70.0
#
#    20:19:00:00:00:08  ...  20:19:00:00:03:22  20:19:00:00:00:58  \
# 0                NaN  ...                NaN              -37.0
# 1              -86.0  ...                NaN              -45.0
# 2              -66.0  ...                NaN              -53.0
# 3              -62.0  ...                NaN              -64.0
# 4                NaN  ...                NaN              -65.0
#
#    20:19:00:00:00:34  20:19:00:00:01:08  20:19:00:00:00:62  20:19:00:00:00:30  \
# 0              -86.0                NaN                NaN                NaN
# 1              -81.0                NaN                NaN                NaN
# 2              -78.0                NaN                NaN                NaN
# 3              -72.0                NaN                NaN                NaN
# 4              -50.0                NaN                NaN                NaN
#
#    20:19:00:00:01:96  20:19:00:00:01:34  20:19:00:00:01:41  20:19:00:00:00:24
# 0                NaN                NaN              -61.0                NaN
# 1                NaN                NaN              -79.0                NaN
# 2              -92.0                NaN                NaN                NaN
# 3                NaN                NaN                NaN                NaN
# 4                NaN                NaN                NaN                NaN
#
# [5 rows x 231 columns]

# %% [markdown]
# # 데이터 분석

# %%
df_data.describe()
# Out:
#         timestamp      region    latitude   longitude  20:19:00:00:03:21  \
# count  103.000000  103.000000  103.000000  103.000000           3.000000
# mean   126.582553    2.000000   43.718411   10.421796         -84.666667
# std     43.881492    1.428011    0.000092    0.000158           0.577350
# min     59.810000    0.000000   43.718253   10.421524         -85.000000
# 25%     86.811000    1.000000   43.718332   10.421660         -85.000000
# 50%    113.787000    2.000000   43.718411   10.421796         -85.000000
# 75%    166.800000    3.000000   43.718490   10.421931         -84.500000
# max    205.701000    4.000000   43.718569   10.422067         -84.000000
#
#        20:19:00:00:02:81  20:19:00:00:01:43  20:19:00:00:03:23  \
# count           4.000000          19.000000           5.000000
# mean          -83.250000         -78.421053         -77.000000
# std             1.707825          14.496420           8.336666
# min           -85.000000         -92.000000         -91.000000
# 25%           -84.250000         -89.000000         -78.000000
# 50%           -83.500000         -86.000000         -73.000000
# 75%           -82.500000         -68.000000         -73.000000
# max           -81.000000         -54.000000         -70.000000
#
#        20:19:00:00:00:98  20:19:00:00:00:08  ...  20:19:00:00:03:22  \
# count          43.000000          71.000000  ...           3.000000
# mean          -65.023256         -77.394366  ...         -84.000000
# std            13.783165           5.750724  ...           1.732051
# min           -87.000000         -89.000000  ...         -85.000000
# 25%           -74.000000         -81.500000  ...         -85.000000
# 50%           -67.000000         -77.000000  ...         -85.000000
# 75%           -59.000000         -74.500000  ...         -83.500000
# max           -35.000000         -62.000000  ...         -82.000000
#
#        20:19:00:00:00:58  20:19:00:00:00:34  20:19:00:00:01:08  \
# count          41.000000          99.000000           3.000000
# mean          -59.878049         -60.555556         -80.000000
# std            14.202456          13.911691           9.643651
# min           -91.000000         -88.000000         -87.000000
# 25%           -68.000000         -71.500000         -85.500000
# 50%           -63.000000         -62.000000         -84.000000
# 75%           -51.000000         -48.000000         -76.500000
# max           -32.000000         -35.000000         -69.000000
#
#        20:19:00:00:00:62  20:19:00:00:00:30  20:19:00:00:01:96  \
# count          13.000000            8.00000                1.0
# mean          -85.307692          -85.62500              -92.0
# std             4.479297            2.66927                NaN
# min           -94.000000          -89.00000              -92.0
# 25%           -89.000000          -88.00000              -92.0
# 50%           -85.000000          -85.50000              -92.0
# 75%           -83.000000          -83.75000              -92.0
# max           -79.000000          -82.00000              -92.0
#
#        20:19:00:00:01:34  20:19:00:00:01:41  20:19:00:00:00:24
# count          11.000000          28.000000           4.000000
# mean          -84.181818         -80.642857         -83.000000
# std             2.400757           9.322272          10.230673
# min           -88.000000         -92.000000         -91.000000
# 25%           -86.000000         -87.250000         -88.000000
# 50%           -84.000000         -82.500000         -86.500000
# 75%           -82.500000         -76.500000         -81.500000
# max           -80.000000         -60.000000         -68.000000
#
# [8 rows x 231 columns]

# %%
# 각 필드별 NaN 갯수 확인
df_data.isna().sum()
# Out:
# timestamp              0
# region                 0
# latitude               0
# longitude              0
# 20:19:00:00:03:21    100
#                     ...
# 20:19:00:00:00:30     95
# 20:19:00:00:01:96    102
# 20:19:00:00:01:34     92
# 20:19:00:00:01:41     75
# 20:19:00:00:00:24     99
# Length: 231, dtype: int64

# %%
isna_dict = dict(df_data.isna().sum())
isna_keys = list(isna_dict.keys())
del_column_idx = []
del_column_names = []
for idx, cnt in enumerate(isna_dict.values()):
    if cnt >= 90:
        print(idx, cnt, isna_keys[idx])
        del_column_idx.append(idx)
        del_column_names.append(isna_keys[idx])
# Out:
# 4 100 20:19:00:00:03:21
# 5 99 20:19:00:00:02:81
# 7 98 20:19:00:00:03:23
# 10 92 20:19:00:00:01:62
# 12 101 20:19:00:00:01:72
# 13 99 20:19:00:00:02:99
# 15 98 20:19:00:00:03:07
# 16 97 20:19:00:00:00:95
# 18 97 20:19:00:00:00:69
# 20 93 20:19:00:00:00:51
# 21 102 20:19:00:00:00:04
# 23 99 20:19:00:00:02:56
# 24 102 20:19:00:00:00:87
# 25 102 20:19:00:00:04:41
# 27 100 20:19:00:00:01:17
# 28 99 20:19:00:00:02:79
# 30 93 20:19:00:00:00:27
# 31 102 20:19:00:00:04:25
# 33 91 20:19:00:00:00:70
# 34 101 20:19:00:00:01:27
# 35 98 20:19:00:00:00:72
# 36 97 20:19:00:00:03:06
# 37 102 20:19:00:00:04:53
# 38 100 20:19:00:00:02:52
# 40 94 20:19:00:00:00:39
# 44 99 20:19:00:00:03:31
# 45 96 20:19:00:00:01:02
# 46 102 20:19:00:00:01:74
# 47 102 20:19:00:00:02:29
# 48 102 20:19:00:00:02:60
# 53 97 20:19:00:00:03:09
# 55 101 20:19:00:00:03:53
# 58 91 20:19:00:00:01:01
# 59 101 20:19:00:00:02:57
# 60 99 20:19:00:00:01:29
# 64 100 20:19:00:00:01:97
# 67 102 20:19:00:00:02:34
# 69 99 20:19:00:00:03:13
# std            12.647702          12.837763          13.700992
# min           -93.000000         -86.000000         -87.000000
# 25%           -89.000000         -68.000000         -73.000000
# 50%           -86.000000         -58.000000         -67.000000
# 75%           -79.000000         -47.000000         -59.000000
# max           -52.000000         -32.000000         -35.000000
#
#        20:19:00:00:00:54  20:19:00:00:01:80  20:19:00:00:00:60  \
# count          45.000000          18.000000          42.000000
# mean          -61.088889         -77.722222         -64.476190
# std            15.440240          14.413252          13.624293
# min           -92.000000         -93.000000         -87.000000
# 25%           -73.000000         -89.000000         -72.750000
# 50%           -64.000000         -85.000000         -67.000000
# 75%           -52.000000         -66.750000         -59.000000
# max           -32.000000         -54.000000         -35.000000
#
#        20:19:00:00:00:58  20:19:00:00:00:34  20:19:00:00:01:41
# count          41.000000          99.000000          28.000000
# mean          -59.878049         -60.555556         -80.642857
# std            14.202456          13.911691           9.322272
# min           -91.000000         -88.000000         -92.000000
# 25%           -68.000000         -71.500000         -87.250000
# 50%           -63.000000         -62.000000         -82.500000
# 75%           -51.000000         -48.000000         -76.500000
# max           -32.000000         -35.000000         -60.000000
#
# [8 rows x 82 columns]

# %% [markdown]
# # 입력데이터 포멧 맞추기

# %%
import numpy as np
ips_data = np.array(df_data)
ips_data[0]
# Out:
# array([ 61.472     ,   0.        ,  43.71827713,  10.42156589,
#                 nan, -37.        ,          nan,          nan,
#        -32.        , -63.        , -36.        , -63.        ,
#                 nan, -33.        ,          nan,          nan,
#                 nan,          nan,          nan, -92.        ,
#                 nan,          nan,          nan,          nan,
#        -60.        ,          nan,          nan,          nan,
#        -62.        ,          nan,          nan,          nan,
#        -86.        , -82.        ,          nan,          nan,
#                 nan, -81.        , -63.        , -81.        ,
#                 nan, -83.        ,          nan,          nan,
#                 nan,          nan, -82.        ,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#        -63.        ,          nan,          nan,          nan,
#        -81.        ,          nan,          nan, -60.        ,
#        -34.        , -34.        , -61.        , -60.        ,
#                 nan,          nan, -81.        , -36.        ,
#        -36.        ,          nan, -36.        , -37.        ,
#        -86.        , -61.        ])

# %% [markdown]
# # AP별로 wifi rssi 신호 특성을 확인

# %%
row = ips_data[0]
print(f"{df_data.columns[1]}/{row[1]}, {df_data.columns[4]}/{row[4]}, {df_data.columns[8]}/{row[8]}")
# Out:
# region/0.0, 20:19:00:00:01:43/nan, 20:19:00:00:00:53/-32.0

# %%
import math
wifi_ap_rssis_dict = {}
for row in ips_data:
    for idx, rssi in enumerate(row[4:]):
        mac = df_data.columns[4+idx]
        if mac not in wifi_ap_rssis_dict.keys():
            wifi_ap_rssis_dict[mac] = {'values':[]}
        if math.isnan(rssi) is False:
            wifi_ap_rssis_dict[mac]['values'].append(rssi)

# wifi_ap_rssis_dict = { mac: {"values":[]}}
# k is mac
# v is {'values'}
           
for v in wifi_ap_rssis_dict.values():
    v['avg'] = sum(v['values'])/len(v['values'])
    v['min'] = min(v['values'])
    v['default'] = -120

# %%
len(wifi_ap_rssis_dict)
# Out:
# 78

# %%
import matplotlib.pyplot as plt
stop_cnt = 5
idx = 1
plt.figure(figsize=(20,4))

for ap, rssis in wifi_ap_rssis_dict.items():
    print(ap, rssis)

    plt.subplot(1,stop_cnt,idx)
    plt.boxplot(rssis['values'])
    
    idx += 1
    if idx > stop_cnt:
        break
# Out:
# 20:19:00:00:01:43 {'values': [-90.0, -54.0, -64.0, -84.0, -92.0, -55.0, -76.0, -90.0, -89.0, -88.0, -89.0, -89.0, -88.0, -54.0, -85.0, -90.0, -86.0, -55.0, -72.0], 'avg': -78.42105263157895, 'min': -92.0, 'default': -120}
# 20:19:00:00:00:98 {'values': [-37.0, -48.0, -66.0, -68.0, -70.0, -86.0, -74.0, -74.0, -68.0, -64.0, -35.0, -50.0, -62.0, -71.0, -75.0, -85.0, -78.0, -77.0, -70.0, -60.0, -53.0, -38.0, -39.0, -59.0, -59.0, -62.0, -70.0, -81.0, -83.0, -87.0, -79.0, -79.0, -68.0, -67.0, -67.0, -37.0, -57.0, -61.0, -73.0, -73.0, -64.0, -67.0, -55.0], 'avg': -65.02325581395348, 'min': -87.0, 'default': -120}
# 20:19:00:00:00:08 {'values': [-86.0, -66.0, -62.0, -79.0, -75.0, -82.0, -83.0, -86.0, -88.0, -87.0, -81.0, -76.0, -75.0, -82.0, -73.0, -66.0, -79.0, -79.0, -73.0, -75.0, -73.0, -77.0, -73.0, -73.0, -75.0, -75.0, -87.0, -83.0, -89.0, -82.0, -78.0, -77.0, -70.0, -79.0, -75.0, -75.0, -83.0, -83.0, -78.0, -69.0, -75.0, -74.0, -78.0, -71.0, -72.0, -78.0, -81.0, -88.0, -81.0, -81.0, -78.0, -79.0, -73.0, -71.0, -72.0, -76.0, -65.0, -75.0, -79.0, -76.0, -75.0, -75.0, -84.0, -84.0, -87.0, -84.0, -77.0, -75.0, -75.0, -75.0, -74.0], 'avg': -77.3943661971831, 'min': -89.0, 'default': -120}
# 20:19:00:00:00:26 {'values': [-85.0, -90.0, -89.0, -88.0, -91.0, -88.0, -90.0, -89.0, -93.0, -93.0, -87.0, -93.0, -93.0, -84.0, -93.0, -88.0, -85.0], 'avg': -89.3529411764706, 'min': -93.0, 'default': -120}
# 20:19:00:00:00:53 {'values': [-32.0, -43.0, -51.0, -66.0, -66.0, -68.0, -73.0, -54.0, -31.0, -40.0, -50.0, -57.0, -64.0, -65.0, -80.0, -89.0, -81.0, -77.0, -73.0, -62.0, -54.0, -34.0, -34.0, -47.0, -52.0, -59.0, -66.0, -76.0, -84.0, -87.0, -78.0, -80.0, -73.0, -68.0, -60.0, -56.0, -35.0, -43.0, -56.0, -67.0, -94.0, -74.0, -66.0, -60.0, -56.0], 'avg': -61.8, 'min': -94.0, 'default': -120}

# %% [markdown]
# # nan 일 경우 해당 AP의 최소 rssi 값으로 대체

# %%
for row in ips_data:
    for idx in range(len(row[4:])):
        col = 4+idx
        mac = df_data.columns[col]
        rssi = row[col]
        if math.isnan(rssi) == True:
            row[col] = wifi_ap_rssis_dict[mac]['min']

# %%
print(ips_data[0])
# Out:
# [ 61.472        0.          43.71827713  10.42156589 -92.
#  -37.         -89.         -93.         -32.         -63.
#  -36.         -63.         -92.         -33.         -89.
#  -90.         -91.         -91.         -93.         -92.
#  -85.         -92.         -84.         -87.         -60.
#  -87.         -90.         -92.         -62.         -94.
#  -89.         -93.         -86.         -82.         -90.
#  -92.         -93.         -81.         -63.         -81.
#  -92.         -83.         -86.         -96.         -88.
#  -92.         -82.         -91.         -89.         -93.
#  -92.         -91.         -87.         -91.         -93.
#  -93.         -90.         -92.         -94.         -91.
#  -63.         -92.         -91.         -90.         -81.
#  -89.         -88.         -60.         -34.         -34.
#  -61.         -60.         -85.         -93.         -81.
#  -36.         -36.         -93.         -36.         -37.
#  -86.         -61.        ]

# %% [markdown]
# # Classifier Model 을 위한 데이터 만들기

# %% [markdown]
# ## STEP1. 입력데이터 포멧 맞추기

# %%
# timestamp, region, latitude, longitude는 training 대상 feature에 서 제외
ips_x = ips_data[:, 4:]
ips_x.shape
# Out:
# (103, 78)

# %%
# region을 class 로 활용하기 위해 두번째 열만으로 하나의 배열을 만듬.
ips_y = ips_data[:, 1:2]
ips_y = ips_y.reshape(-1)
ips_y = ips_y.astype(np.int32)
print(ips_y)
# Out:
# [0 0 1 1 1 2 2 3 3 3 4 4 4 4 4 3 3 2 2 2 1 1 0 0 0 0 0 1 1 1 2 2 2 3 3 3 4
#  4 4 4 4 3 3 2 2 2 1 1 0 0 0 0 0 0 1 1 1 2 2 2 3 3 3 4 4 4 4 4 4 3 3 3 2 2
#  2 1 1 1 0 0 0 0 0 1 1 2 2 3 3 4 4 4 4 4 3 3 2 2 1 1 0 0 0]

# %% [markdown]
# ## STEP2. Training & Test set 으로 나눠주기

# %%
from sklearn import model_selection

train_x, test_x, train_y, test_y = model_selection.train_test_split(ips_x, ips_y, test_size=0.3, shuffle=False)

print("x_train:", train_x.shape, "y_train:", train_y.shape)
print("x_test: ", test_x.shape, "y_test: ", test_y.shape)
# Out:
# x_train: (72, 78) y_train: (72,)
# x_test:  (31, 78) y_test:  (31,)

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

model = KNeighborsClassifier() # 모델 생성
model.fit(train_x, train_y)    # 모델 학습
# Out:
# KNeighborsClassifier()

# %%
model.score(test_x, test_y)
# Out:
# 0.5161290322580645

# %%
hit = 0
total = 0
results = []
for idx in range(len(test_x)):
    actual = test_y[idx]
    predicted = model.predict(test_x[idx].reshape(1,-1))
    total += 1
    print(f"[{idx:02d}] actual={actual}, predicted={predicted} - {actual==predicted}")
    if actual == predicted[0]:
        results.append(True)
        hit += 1
    else:
        results.append(False)

print(f"Accuracy: {hit/total} ({hit}/{total})")
# Out:
# [00] actual=2, predicted=[2] - [ True]
# [01] actual=2, predicted=[2] - [ True]
# [02] actual=2, predicted=[3] - [False]
# [03] actual=1, predicted=[2] - [False]
# [04] actual=1, predicted=[1] - [ True]
# [05] actual=1, predicted=[1] - [ True]
# [06] actual=0, predicted=[1] - [False]
# [07] actual=0, predicted=[1] - [False]
# [08] actual=0, predicted=[0] - [ True]
# [09] actual=0, predicted=[0] - [ True]
# [10] actual=0, predicted=[0] - [ True]
# [11] actual=1, predicted=[1] - [ True]
# [12] actual=1, predicted=[1] - [ True]
# [13] actual=2, predicted=[2] - [ True]
# [14] actual=2, predicted=[3] - [False]
# [15] actual=3, predicted=[2] - [False]
# [16] actual=3, predicted=[2] - [False]
# [17] actual=4, predicted=[3] - [False]
# [18] actual=4, predicted=[3] - [False]
# [19] actual=4, predicted=[4] - [ True]
# [20] actual=4, predicted=[4] - [ True]
# [21] actual=4, predicted=[4] - [ True]
# [22] actual=3, predicted=[3] - [ True]
# [23] actual=3, predicted=[2] - [False]
# [24] actual=2, predicted=[3] - [False]
# [25] actual=2, predicted=[3] - [False]
# [26] actual=1, predicted=[2] - [False]
# [27] actual=1, predicted=[1] - [ True]
# [28] actual=0, predicted=[1] - [False]
# [29] actual=0, predicted=[1] - [False]
# [30] actual=0, predicted=[0] - [ True]
# Accuracy: 0.5161290322580645 (16/31)

# %%
colors = ['blue' if r == True else 'red' for r in results]

# %% [markdown]
# # 좌표

# %%
latitudes = ips_data[72:, 2:3]
latitudes = latitudes.reshape(-1)
longitudes = ips_data[72:, 3:4]
longitudes = longitudes.reshape(-1)

# %%
import matplotlib.pyplot as plt
plt.scatter(latitudes, longitudes, c=colors)
plt.show()

# %% [markdown]
# ## SVM

# %%
from sklearn import svm

model = svm.SVC() # 모델 생성
model.fit(train_x, train_y)    # 모델 학습
# Out:
# SVC()

# %%
model.score(test_x, test_y)
# Out:
# 0.7096774193548387

# %%
def display(test_x, test_y, models):
    hit = 0
    total = 0
    results = []
    for idx in range(len(test_x)):
        actual = test_y[idx]
        predicted = model.predict(test_x[idx].reshape(1,-1))
        total += 1
        print(f"[{idx:02d}] actual={actual}, predicted={predicted} - {actual==predicted}")
        if actual == predicted[0]:
            results.append(True)
            hit += 1
        else:
            results.append(False)

    print(f"Accuracy: {hit/total} ({hit}/{total})")
    
    return results

# %%
results = display(test_x, test_y, model)
colors = ['blue' if r == True else 'red' for r in results]
# Out:
# [00] actual=2, predicted=[2] - [ True]
# [01] actual=2, predicted=[2] - [ True]
# [02] actual=2, predicted=[2] - [ True]
# [03] actual=1, predicted=[2] - [False]
# [04] actual=1, predicted=[2] - [False]
# [05] actual=1, predicted=[1] - [ True]
# [06] actual=0, predicted=[1] - [False]
# [07] actual=0, predicted=[0] - [ True]
# [08] actual=0, predicted=[0] - [ True]
# [09] actual=0, predicted=[0] - [ True]
# [10] actual=0, predicted=[0] - [ True]
# [11] actual=1, predicted=[1] - [ True]
# [12] actual=1, predicted=[1] - [ True]
# [13] actual=2, predicted=[2] - [ True]
# [14] actual=2, predicted=[2] - [ True]
# [15] actual=3, predicted=[2] - [False]
# [16] actual=3, predicted=[2] - [False]
# [17] actual=4, predicted=[3] - [False]
# [18] actual=4, predicted=[4] - [ True]
# [19] actual=4, predicted=[4] - [ True]
# [20] actual=4, predicted=[4] - [ True]
# [21] actual=4, predicted=[4] - [ True]
# [22] actual=3, predicted=[4] - [False]
# [23] actual=3, predicted=[3] - [ True]
# [24] actual=2, predicted=[2] - [ True]
# [25] actual=2, predicted=[2] - [ True]
# [26] actual=1, predicted=[2] - [False]
# [27] actual=1, predicted=[1] - [ True]
# [28] actual=0, predicted=[1] - [False]
# [29] actual=0, predicted=[0] - [ True]
# [30] actual=0, predicted=[0] - [ True]
# Accuracy: 0.7096774193548387 (22/31)

# %%
import matplotlib.pyplot as plt
plt.scatter(latitudes, longitudes, c=colors)
plt.show()

# %% [markdown]
# ## GaussianProcessClassifier

# %%
from sklearn.gaussian_process import GaussianProcessClassifier
model = GaussianProcessClassifier() # 모델 생성
model.fit(train_x, train_y)    # 모델 학습
# Out:
# GaussianProcessClassifier()

# %%
model.score(test_x, test_y)
# Out:
# 0.16129032258064516

# %% [markdown]
# # sklearn classifiers
# https://scikit-learn.org/stable/auto_examples/classification/plot_classifier_comparison.html
